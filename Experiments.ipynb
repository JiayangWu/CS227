# %%
import sys
sys.path.append("/Users/fsolleza/Documents/Projects/timeseries-data") # path to this repository
import py_ts_data
import time
import random
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import datetime
import math
from kshape import _sbd as SBD
from auto_encoder import AutoEncoder, train_step, LSTM_Ae

X_train, y_train, X_test, y_test, info = py_ts_data.load_data("GunPoint", variables_as_channels=True)
print("Dataset shape: Train: {}, Test: {}".format(X_train.shape, X_test.shape))
print(np.shape(y_train))
# Out:
# Dataset shape: Train: (50, 150, 1), Test: (150, 150, 1)
# (50,)

# %%
def normalize(data):
    """
    Z-normalize data with shape (x, y)
    x = # of timeseries
    y = len of each timeseries
    
    s.t. each array in [., :, .] (i.e. each timeseries variable)
    is zero-mean and unit stddev
    """
    # sz, l = data.shape
    means = np.mean(data)
    stddev = np.std(data)
    return (data - means)/stddev

def flatten_and_normalize(tensor):
    # print(tf.reshape(tensor,[-1]))
    return normalize(tf.reshape(tensor,[-1]))
    
def augment_data(X_train, K = 1000, alpha = 0.1):
    # K is the target size, alpha is the fluctuated rate of fabricated data.
    repeat_times = K // len(X_train)
    new_x_data = None

    for _ in range(repeat_times):
        #for x_series, y_series in zip(X_train, y_train):
        for x_series in X_train:
            x_noise = 1 - 0.1 * (np.random.random(x_series.shape) - 0.5)

            new_x_series = np.reshape(x_series * x_noise, (1, len(x_series), 1))

            if new_x_data is None:
                new_x_data = new_x_series
            else:
                new_x_data = np.append(new_x_data, new_x_series, axis = 0)

    print("The original data shape is:", np.shape(X_train))
    X_train = np.append(X_train, new_x_data, axis = 0)
    print("The augmented data shape is:", np.shape(X_train))

    return X_train

#X_train= augment_data(X_train)
num_train = len(X_train)
indices1 = np.random.choice(num_train, int(num_train * math.log2(num_train)))
indices2 = np.random.choice(num_train, int(num_train * math.log2(num_train)))

X = X_train[indices1]
Y = X_train[indices2]
print('X shape: ', X.shape)
print('Y shape: ', Y.shape)
# normalized_X = flatten_and_normalize(X)
# normalized_Y = flatten_and_normalize(Y)
normalized_X = normalize(X)
normalized_Y = normalize(Y)

normalized_X_2d = normalize(X).squeeze()
normalized_Y_2d = normalize(Y).squeeze()


print('normalized_X shape: ', normalized_X.shape)
print('normalized_Y shape: ', normalized_Y.shape)
distance = []
for x, y in zip(normalized_X_2d, normalized_Y_2d):
    distance.append(SBD(x, y))
distance = np.array(distance)
print('distance shape: ', distance.shape)
#distance = SBD(normalized_X, normalized_Y)
# Out:
# X shape:  (282, 150, 1)
# Y shape:  (282, 150, 1)
# normalized_X shape:  (282, 150, 1)
# normalized_Y shape:  (282, 150, 1)
# distance shape:  (282,)

# %%
def min_max(data, feature_range=(0, 1)):
    """
    implements min-max scaler
    """
    min_v = feature_range[0]
    max_v = feature_range[1]
    max_vals = data.max(axis=1)[:, None, :]
    min_vals = data.min(axis=1)[:, None, :]
    X_std = (data - min_vals) / (max_vals - min_vals)
    return X_std * (max_v - min_v) + min_v

def normalize(data):
    """
    Z-normalize data with shape (x, y, z)
    x = # of timeseries
    y = len of each timeseries
    z = vars in each timeseres
    
    s.t. each array in [., :, .] (i.e. each timeseries variable)
    is zero-mean and unit stddev
    """
    sz, l, d = data.shape
    means = np.broadcast_to(np.mean(data, axis=1)[:, None, :], (sz, l, d))
    stddev = np.broadcast_to(np.std(data, axis=1)[:, None, :], (sz, l, d)) 
    return (data - means)/stddev

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 3))
axs[0].plot(X_train[0])
X_train = min_max(X_train, feature_range=(-1, 1))
axs[1].plot(X_train[0])
X_test = min_max(X_test, feature_range=(-1, 1))
plt.show()

# %% [markdown]
# # Encode and Decode

# %%
kwargs = {
    # "input_shape": (X.shape[1], X.shape[2]),
    # "filters": [32, 64, 128],
    # "kernel_sizes": [5, 5, 5],
    # "code_size": 16,

    # "input_shape": (X_train.shape[1], X_train.shape[2]),
    # "filters": [32, 64, 128],
    # "kernel_sizes": [5, 5, 5],
    # "code_size": 16,
    "input": X,
    
}

#ae = AutoEncoder(**kwargs)
lstm_ae = LSTM_Ae(**kwargs)

# %% [markdown]
# # Training

# %%
EPOCHS = 500
# SHUFFLE_BUFFER = 100
# K = len(set(y_train))

# train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
# train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER).batch(BATCH)

loss_history = []
t1 = time.time()
for epoch in range(EPOCHS):
    #total_loss = train_step(X_train, ae)
    total_loss = train_step(normalized_X, normalized_Y, distance, lstm_ae)

    # for i, (input, _) in enumerate(train_dataset):
    #     loss = train_step(input, ae)
    # total_loss += loss
    loss_history.append(total_loss)
    #print("Epoch {}: {}".format(epoch, total_loss), end="\r")
    print("Epoch: ", epoch)
    print("loss: ", total_loss)
    
print("The training time is:", time.time() - t1)
plt.plot(loss_history)
# Out:
# 03243, shape=(), dtype=float32)
# Epoch:  363
# loss:  tf.Tensor(3.7342627, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9199376, shape=(), dtype=float32)
# Epoch:  364
# loss:  tf.Tensor(3.735512, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91955155, shape=(), dtype=float32)
# Epoch:  365
# loss:  tf.Tensor(3.736761, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9191661, shape=(), dtype=float32)
# Epoch:  366
# loss:  tf.Tensor(3.7380092, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91878104, shape=(), dtype=float32)
# Epoch:  367
# loss:  tf.Tensor(3.7392566, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9183965, shape=(), dtype=float32)
# Epoch:  368
# loss:  tf.Tensor(3.7405033, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9180125, shape=(), dtype=float32)
# Epoch:  369
# loss:  tf.Tensor(3.7417493, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.917629, shape=(), dtype=float32)
# Epoch:  370
# loss:  tf.Tensor(3.7429945, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91724604, shape=(), dtype=float32)
# Epoch:  371
# loss:  tf.Tensor(3.744239, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91686356, shape=(), dtype=float32)
# Epoch:  372
# loss:  tf.Tensor(3.745483, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9164816, shape=(), dtype=float32)
# Epoch:  373
# loss:  tf.Tensor(3.746726, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9161002, shape=(), dtype=float32)
# Epoch:  374
# loss:  tf.Tensor(3.7479684, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9157194, shape=(), dtype=float32)
# Epoch:  375
# loss:  tf.Tensor(3.7492104, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9153389, shape=(), dtype=float32)
# Epoch:  376
# loss:  tf.Tensor(3.750451, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9149591, shape=(), dtype=float32)
# Epoch:  377
# loss:  tf.Tensor(3.7516913, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91457963, shape=(), dtype=float32)
# Epoch:  378
# loss:  tf.Tensor(3.752931, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91420066, shape=(), dtype=float32)
# Epoch:  379
# loss:  tf.Tensor(3.75417, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91382235, shape=(), dtype=float32)
# Epoch:  380
# loss:  tf.Tensor(3.7554083, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9134445, shape=(), dtype=float32)
# Epoch:  381
# loss:  tf.Tensor(3.7566454, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9130671, shape=(), dtype=float32)
# Epoch:  382
# loss:  tf.Tensor(3.757882, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9126903, shape=(), dtype=float32)
# Epoch:  383
# loss:  tf.Tensor(3.759118, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9123139, shape=(), dtype=float32)
# Epoch:  384
# loss:  tf.Tensor(3.7603536, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9119381, shape=(), dtype=float32)
# Epoch:  385
# loss:  tf.Tensor(3.761588, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9115627, shape=(), dtype=float32)
# Epoch:  386
# loss:  tf.Tensor(3.7628224, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91118777, shape=(), dtype=float32)
# Epoch:  387
# loss:  tf.Tensor(3.7640557, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91081333, shape=(), dtype=float32)
# Epoch:  388
# loss:  tf.Tensor(3.7652884, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9104395, shape=(), dtype=float32)
# Epoch:  389
# loss:  tf.Tensor(3.7665203, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.91006607, shape=(), dtype=float32)
# Epoch:  390
# loss:  tf.Tensor(3.7677515, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90969324, shape=(), dtype=float32)
# Epoch:  391
# loss:  tf.Tensor(3.7689817, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9093207, shape=(), dtype=float32)
# Epoch:  392
# loss:  tf.Tensor(3.7702112, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9089488, shape=(), dtype=float32)
# Epoch:  393
# loss:  tf.Tensor(3.7714405, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9085773, shape=(), dtype=float32)
# Epoch:  394
# loss:  tf.Tensor(3.7726688, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9082064, shape=(), dtype=float32)
# Epoch:  395
# loss:  tf.Tensor(3.773897, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90783596, shape=(), dtype=float32)
# Epoch:  396
# loss:  tf.Tensor(3.775124, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90746593, shape=(), dtype=float32)
# Epoch:  397
# loss:  tf.Tensor(3.7763503, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90709645, shape=(), dtype=float32)
# Epoch:  398
# loss:  tf.Tensor(3.777576, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9067273, shape=(), dtype=float32)
# Epoch:  399
# loss:  tf.Tensor(3.778801, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9063589, shape=(), dtype=float32)
# Epoch:  400
# loss:  tf.Tensor(3.7800255, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9059907, shape=(), dtype=float32)
# Epoch:  401
# loss:  tf.Tensor(3.781249, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9056232, shape=(), dtype=float32)
# Epoch:  402
# loss:  tf.Tensor(3.7824721, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90525615, shape=(), dtype=float32)
# Epoch:  403
# loss:  tf.Tensor(3.7836947, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90488935, shape=(), dtype=float32)
# Epoch:  404
# loss:  tf.Tensor(3.7849164, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9045232, shape=(), dtype=float32)
# Epoch:  405
# loss:  tf.Tensor(3.7861373, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9041574, shape=(), dtype=float32)
# Epoch:  406
# loss:  tf.Tensor(3.7873578, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90379226, shape=(), dtype=float32)
# Epoch:  407
# loss:  tf.Tensor(3.7885776, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9034275, shape=(), dtype=float32)
# Epoch:  408
# loss:  tf.Tensor(3.7897964, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9030633, shape=(), dtype=float32)
# Epoch:  409
# loss:  tf.Tensor(3.7910147, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9026995, shape=(), dtype=float32)
# Epoch:  410
# loss:  tf.Tensor(3.7922323, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90233606, shape=(), dtype=float32)
# Epoch:  411
# loss:  tf.Tensor(3.7934492, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90197325, shape=(), dtype=float32)
# Epoch:  412
# loss:  tf.Tensor(3.7946653, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90161085, shape=(), dtype=float32)
# Epoch:  413
# loss:  tf.Tensor(3.795881, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90124893, shape=(), dtype=float32)
# Epoch:  414
# loss:  tf.Tensor(3.7970958, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90088737, shape=(), dtype=float32)
# Epoch:  415
# loss:  tf.Tensor(3.7983098, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.9005264, shape=(), dtype=float32)
# Epoch:  416
# loss:  tf.Tensor(3.7995234, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.90016586, shape=(), dtype=float32)
# Epoch:  417
# loss:  tf.Tensor(3.8007364, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8998058, shape=(), dtype=float32)
# Epoch:  418
# loss:  tf.Tensor(3.8019488, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89944625, shape=(), dtype=float32)
# Epoch:  419
# loss:  tf.Tensor(3.8031604, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89908695, shape=(), dtype=float32)
# Epoch:  420
# loss:  tf.Tensor(3.8043714, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89872825, shape=(), dtype=float32)
# Epoch:  421
# loss:  tf.Tensor(3.8055816, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89837, shape=(), dtype=float32)
# Epoch:  422
# loss:  tf.Tensor(3.806791, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89801216, shape=(), dtype=float32)
# Epoch:  423
# loss:  tf.Tensor(3.8079998, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89765495, shape=(), dtype=float32)
# Epoch:  424
# loss:  tf.Tensor(3.8092082, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8972981, shape=(), dtype=float32)
# Epoch:  425
# loss:  tf.Tensor(3.8104157, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89694154, shape=(), dtype=float32)
# Epoch:  426
# loss:  tf.Tensor(3.8116221, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8965856, shape=(), dtype=float32)
# Epoch:  427
# loss:  tf.Tensor(3.8128285, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8962301, shape=(), dtype=float32)
# Epoch:  428
# loss:  tf.Tensor(3.8140345, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.895875, shape=(), dtype=float32)
# Epoch:  429
# loss:  tf.Tensor(3.8152392, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8955203, shape=(), dtype=float32)
# Epoch:  430
# loss:  tf.Tensor(3.816444, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89516616, shape=(), dtype=float32)
# Epoch:  431
# loss:  tf.Tensor(3.8176475, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89481235, shape=(), dtype=float32)
# Epoch:  432
# loss:  tf.Tensor(3.8188505, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.894459, shape=(), dtype=float32)
# Epoch:  433
# loss:  tf.Tensor(3.8200529, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89410615, shape=(), dtype=float32)
# Epoch:  434
# loss:  tf.Tensor(3.8212547, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.89375377, shape=(), dtype=float32)
# Epoch:  435
# loss:  tf.Tensor(3.822456, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8934018, shape=(), dtype=float32)
# Epoch:  436
# loss:  tf.Tensor(3.8236563, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8930502, shape=(), dtype=float32)
# Epoch:  437
# loss:  tf.Tensor(3.824856, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8926991, shape=(), dtype=float32)
# Epoch:  438
# loss:  tf.Tensor(3.826055, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8923485, shape=(), dtype=float32)
# Epoch:  439
# loss:  tf.Tensor(3.8272536, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8919983, shape=(), dtype=float32)
# Epoch:  440
# loss:  tf.Tensor(3.8284514, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8916485, shape=(), dtype=float32)
# Epoch:  441
# loss:  tf.Tensor(3.8296485, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8912991, shape=(), dtype=float32)
# Epoch:  442
# loss:  tf.Tensor(3.8308449, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8909502, shape=(), dtype=float32)
# Epoch:  443
# loss:  tf.Tensor(3.8320408, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8906019, shape=(), dtype=float32)
# Epoch:  444
# loss:  tf.Tensor(3.833236, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8902537, shape=(), dtype=float32)
# Epoch:  445
# loss:  tf.Tensor(3.8344305, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8899062, shape=(), dtype=float32)
# Epoch:  446
# loss:  tf.Tensor(3.8356242, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88955903, shape=(), dtype=float32)
# Epoch:  447
# loss:  tf.Tensor(3.8368175, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88921237, shape=(), dtype=float32)
# Epoch:  448
# loss:  tf.Tensor(3.83801, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88886607, shape=(), dtype=float32)
# Epoch:  449
# loss:  tf.Tensor(3.839202, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8885201, shape=(), dtype=float32)
# Epoch:  450
# loss:  tf.Tensor(3.8403935, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8881748, shape=(), dtype=float32)
# Epoch:  451
# loss:  tf.Tensor(3.8415842, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88782966, shape=(), dtype=float32)
# Epoch:  452
# loss:  tf.Tensor(3.842774, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88748515, shape=(), dtype=float32)
# Epoch:  453
# loss:  tf.Tensor(3.8439636, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.887141, shape=(), dtype=float32)
# Epoch:  454
# loss:  tf.Tensor(3.8451524, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88679725, shape=(), dtype=float32)
# Epoch:  455
# loss:  tf.Tensor(3.8463402, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88645405, shape=(), dtype=float32)
# Epoch:  456
# loss:  tf.Tensor(3.8475277, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8861111, shape=(), dtype=float32)
# Epoch:  457
# loss:  tf.Tensor(3.8487144, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88576865, shape=(), dtype=float32)
# Epoch:  458
# loss:  tf.Tensor(3.8499005, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8854267, shape=(), dtype=float32)
# Epoch:  459
# loss:  tf.Tensor(3.851086, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8850851, shape=(), dtype=float32)
# Epoch:  460
# loss:  tf.Tensor(3.8522706, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.884744, shape=(), dtype=float32)
# Epoch:  461
# loss:  tf.Tensor(3.8534548, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8844032, shape=(), dtype=float32)
# Epoch:  462
# loss:  tf.Tensor(3.8546383, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8840629, shape=(), dtype=float32)
# Epoch:  463
# loss:  tf.Tensor(3.8558211, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8837229, shape=(), dtype=float32)
# Epoch:  464
# loss:  tf.Tensor(3.8570032, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8833834, shape=(), dtype=float32)
# Epoch:  465
# loss:  tf.Tensor(3.8581848, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88304436, shape=(), dtype=float32)
# Epoch:  466
# loss:  tf.Tensor(3.859366, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8827057, shape=(), dtype=float32)
# Epoch:  467
# loss:  tf.Tensor(3.860546, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8823675, shape=(), dtype=float32)
# Epoch:  468
# loss:  tf.Tensor(3.8617253, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8820297, shape=(), dtype=float32)
# Epoch:  469
# loss:  tf.Tensor(3.8629045, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8816923, shape=(), dtype=float32)
# Epoch:  470
# loss:  tf.Tensor(3.8640828, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8813553, shape=(), dtype=float32)
# Epoch:  471
# loss:  tf.Tensor(3.8652604, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8810188, shape=(), dtype=float32)
# Epoch:  472
# loss:  tf.Tensor(3.8664377, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8806826, shape=(), dtype=float32)
# Epoch:  473
# loss:  tf.Tensor(3.8676138, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8803469, shape=(), dtype=float32)
# Epoch:  474
# loss:  tf.Tensor(3.8687897, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.88001156, shape=(), dtype=float32)
# Epoch:  475
# loss:  tf.Tensor(3.8699646, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8796768, shape=(), dtype=float32)
# Epoch:  476
# loss:  tf.Tensor(3.871139, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8793422, shape=(), dtype=float32)
# Epoch:  477
# loss:  tf.Tensor(3.8723125, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8790081, shape=(), dtype=float32)
# Epoch:  478
# loss:  tf.Tensor(3.8734858, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87867445, shape=(), dtype=float32)
# Epoch:  479
# loss:  tf.Tensor(3.8746583, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8783412, shape=(), dtype=float32)
# Epoch:  480
# loss:  tf.Tensor(3.8758302, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87800825, shape=(), dtype=float32)
# Epoch:  481
# loss:  tf.Tensor(3.8770013, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87767583, shape=(), dtype=float32)
# Epoch:  482
# loss:  tf.Tensor(3.8781717, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8773438, shape=(), dtype=float32)
# Epoch:  483
# loss:  tf.Tensor(3.8793416, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87701225, shape=(), dtype=float32)
# Epoch:  484
# loss:  tf.Tensor(3.8805108, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87668097, shape=(), dtype=float32)
# Epoch:  485
# loss:  tf.Tensor(3.881679, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87635016, shape=(), dtype=float32)
# Epoch:  486
# loss:  tf.Tensor(3.882847, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8760197, shape=(), dtype=float32)
# Epoch:  487
# loss:  tf.Tensor(3.8840144, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87568974, shape=(), dtype=float32)
# Epoch:  488
# loss:  tf.Tensor(3.885181, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87536013, shape=(), dtype=float32)
# Epoch:  489
# loss:  tf.Tensor(3.8863468, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8750309, shape=(), dtype=float32)
# Epoch:  490
# loss:  tf.Tensor(3.8875122, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8747021, shape=(), dtype=float32)
# Epoch:  491
# loss:  tf.Tensor(3.8886771, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.87437356, shape=(), dtype=float32)
# Epoch:  492
# loss:  tf.Tensor(3.889841, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8740456, shape=(), dtype=float32)
# Epoch:  493
# loss:  tf.Tensor(3.8910048, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.873718, shape=(), dtype=float32)
# Epoch:  494
# loss:  tf.Tensor(3.8921676, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8733908, shape=(), dtype=float32)
# Epoch:  495
# loss:  tf.Tensor(3.8933296, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8730639, shape=(), dtype=float32)
# Epoch:  496
# loss:  tf.Tensor(3.8944912, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8727375, shape=(), dtype=float32)
# Epoch:  497
# loss:  tf.Tensor(3.8956518, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8724114, shape=(), dtype=float32)
# Epoch:  498
# loss:  tf.Tensor(3.896812, shape=(), dtype=float32)
# X.shape:  (282, 150, 1)
# rec_loss:  tf.Tensor(0.8720859, shape=(), dtype=float32)
# Epoch:  499
# loss:  tf.Tensor(3.8979716, shape=(), dtype=float32)
# The training time is: 318.2877540588379

# %% [markdown]
# # Test

# %% [markdown]
# ## Evaluate reconstruction

# %%
X_codes, encoder_last_input_X, encoder_last_cell_state_X = lstm_ae.encoder(X_test)
X_decodes, decoder_last_input_X, decoder_last_cell_state_X = lstm_ae.decoder(X_codes)
print(X_codes.shape)
print(X_decodes.shape)
plt.plot(X_test[0])
#plt.plot(code_test)
plt.plot(np.array(X_decodes[0]).squeeze())
plt.show()

losses = []
for ground, predict in zip(X_test, X_decodes):
    losses.append(np.linalg.norm(ground - predict))
print("Mean L2 distance: {}".format(np.array(losses).mean()))
# code_test = lstm_ae.encoder(X_test)
# decoded_test = lstm_ae.decoder(code_test)
# print(decoded_test)
# plt.plot(X_test[0])
# #plt.plot(code_test)
# plt.plot(np.array(decoded_test[0]).squeeze())
# plt.show()

# code_test = np.squeeze(np.array(code_test), axis=2)
# decoded_test = np.squeeze(np.array(decoded_test), axis=2)
# losses = []
# for ground, predict in zip(code_test, decoded_test):
#     losses.append(np.linalg.norm(ground - predict))
# print("Mean L2 distance: {}".format(np.array(losses).mean()))
# Out:
# (150, 150, 1)
# (150, 150, 1)
# Mean L2 distance: 6.2920660972595215

# %% [markdown]
# ## Evaluate Similarity

# %%
from sklearn.neighbors import NearestNeighbors

def nn_dist(x, y):
    """
    Sample distance metric, here, using only Euclidean distance
    """
    #x = x.reshape((50, 2))
    #y = y.reshape((50, 2))
    return np.linalg.norm(x-y)

#X_codes_test = np.array(X_codes).reshape((-1, 100))
#nn_x_test = X_test.reshape((-1, 100))
X_codes_test = np.array(X_codes).reshape((-1, np.shape(X)[1]))
nn_x_test = X_test.reshape((-1, np.shape(X)[1]))
print('X_codes shape: ', X_codes.shape)
print('X_codes_test shape: ', X_codes_test.shape)
print('X_test shape: ', X_test.shape)
print('nn_x_test shape: ', nn_x_test.shape)

baseline_nn = NearestNeighbors(n_neighbors=10, metric=nn_dist).fit(nn_x_test)
code_nn = NearestNeighbors(n_neighbors=10).fit(X_codes_test)

# For each item in the test data, find its 11 nearest neighbors in that dataset (the nn is itself)
baseline_11nn = baseline_nn.kneighbors(nn_x_test, 11, return_distance=False)
code_11nn     = code_nn.kneighbors(X_codes_test, 11, return_distance=False)

# On average, how many common items are in the 10nn?
result = []
for b, c in zip(baseline_11nn, code_11nn):
    # remove the first nn (itself)
    b = set(b[1:])
    c = set(c[1:])
    result.append(len(b.intersection(c)))
np.array(result).mean()
# Out:
# X_codes shape:  (150, 150, 1)
# X_codes_test shape:  (150, 150)
# X_test shape:  (150, 150, 1)
# nn_x_test shape:  (150, 150)
# 8.76
